# %% [markdown]
# <a href="https://colab.research.google.com/github/Deventhefire/Python-Data-Visualisation/blob/main/DV_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import numpy as np
import pandas as pd
import seaborn as sns
from numpy.random import randn, randint, uniform, sample
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Question 1:
#  Create a dataframe with 10 rows on random numbers and 4 columns, (columns labelled as a,b,c,d) and plot a bar chart.

# %%
dff = pd.DataFrame(randn(10,4), columns=['a','b','c','d'])
dff.plot(kind='bar', figsize=(15,10))
plt.show()
